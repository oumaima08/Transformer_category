# %%
import pandas as pd

# Exemple de DataFrame (colonne catégorie)
data = {
    'product_id': [1, 2, 3, 4, 5],
    'product_name': ['Laptop', 'Smartphone', 'Desk', 'Chair', 'Headphones'],
    'category': ['Electronics', 'Electronics', 'Furniture', 'Furniture', 'Electronics'],
    'price': [1200.50, 799.99, 300.00, 150.75, 199.99]
}

df= pd.DataFrame(data)
print("DataFrame :")
print(df)
# Out:
# DataFrame :
#    product_id product_name     category    price
# 0           1       Laptop  Electronics  1200.50
# 1           2   Smartphone  Electronics   799.99
# 2           3         Desk    Furniture   300.00
# 3           4        Chair    Furniture   150.75
# 4           5   Headphones  Electronics   199.99

# %%
# Encodage binaire
df['category'] = df['category'].map({'Electronics': 0, 'Furniture': 1})
df.head()
# Out:
#    product_id product_name  category    price
# 0           1       Laptop         0  1200.50
# 1           2   Smartphone         0   799.99
# 2           3         Desk         1   300.00
# 3           4        Chair         1   150.75
# 4           5   Headphones         0   199.99

# %%
# Encodage one-Hot
print(df['product_name'].dtype)
df['product_name'] = df['product_name'].astype('category')
df_encoded = pd.get_dummies(df, columns=['product_name', ], dtype=int)
print(df_encoded.iloc[0,:])
df_encoded.head()
# Out:
# category
# product_id                    1.0
# category                      0.0
# price                      1200.5
# product_name_Chair            0.0
# product_name_Desk             0.0
# product_name_Headphones       0.0
# product_name_Laptop           1.0
# product_name_Smartphone       0.0
# Name: 0, dtype: float64
#    product_id  category    price  product_name_Chair  product_name_Desk  \
# 0           1         0  1200.50                   0                  0
# 1           2         0   799.99                   0                  0
# 2           3         1   300.00                   0                  1
# 3           4         1   150.75                   1                  0
# 4           5         0   199.99                   0                  0
#
#    product_name_Headphones  product_name_Laptop  product_name_Smartphone
# 0                        0                    1                        0
# 1                        0                    0                        1
# ...
